# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYALI-bhunia/DEEP_LEARNING/blob/main/TextPrep.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/COVID-19 AR Clinical Correlates July202020_1.csv")
print(df.shape)
df.head()
# Out:
# (260, 7)
#              Unnamed: 0  ...                                         Unnamed: 6
# 0            patient_id  ...                           Radiologist KEY FINDINGS
# 1  COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2  COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3  COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4  COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
#
# [5 rows x 7 columns]

# %%
df.columns=df.iloc[0]
df=df[1:]
df
# Out:
# 0              patient_id  ...                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  ...  Mild dependent atelectatic changes are seen in...
# ..                    ...  ...                                                ...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
# 257                   NaN  ...                                                NaN
# 258                   NaN  ...                                                NaN
# 259                   NaN  ...                                                NaN
#
# [259 rows x 7 columns]

# %%
df.columns
# Out:
# Index(['patient_id', 'Diag to img study (days)',
#        'Diagnosis to Imaging time (hrs)', 'Image Study Description',
#        'study modality', 'FIO2 @ time of img study',
#        'Radiologist KEY FINDINGS'],
#       dtype='object', name=0)

# %%
df=df[['patient_id','Image Study Description','study modality','Radiologist KEY FINDINGS']]
df
# Out:
# 0              patient_id  ...                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  ...  Mild dependent atelectatic changes are seen in...
# ..                    ...  ...                                                ...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
# 257                   NaN  ...                                                NaN
# 258                   NaN  ...                                                NaN
# 259                   NaN  ...                                                NaN
#
# [259 rows x 4 columns]

# %%
df.dropna(inplace=True)
print(df.shape)
# Out:
# (256, 4)
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df
# Out:
# 0              patient_id  ...                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  ...  Mild dependent atelectatic changes are seen in...
# ..                    ...  ...                                                ...
# 252  COVID-19-AR-16439200  ...  Lungs are moderately inflated but there are wo...
# 253  COVID-19-AR-16439190  ...  Diffusely distributed throughout the lungs are...
# 254  COVID-19-AR-16445122  ...  Multiple bilateral diffuse peripheral areas of...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
#
# [256 rows x 4 columns]

# %%
df['patient_id'].value_counts()
# Out:
# COVID-19-AR-16424111    16
# COVID-19-AR-16406531    10
# COVID-19-AR-16439192     7
# COVID-19-AR-16406542     6
# COVID-19-AR-16407183     6
#                         ..
# COVID-19-AR-16445167     1
# COVID-19-AR-16434346     1
# COVID-19-AR-16424077     1
# COVID-19-AR-16434391     1
# COVID-19-AR-16445149     1
# Name: patient_id, Length: 105, dtype: int64

# %%
df=df[['patient_id','Image Study Description','study modality','Radiologist KEY FINDINGS']]

df.rename(columns={'Image Study Description' : 'Image_Study_Description', 'study modality': 'study_modality', 'Radiologist KEY FINDINGS': 'Radiologist_KEY_FINDINGS' }, inplace=True)
df
# Out:
# 0              patient_id  ...                           Radiologist_KEY_FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  ...  Mild dependent atelectatic changes are seen in...
# ..                    ...  ...                                                ...
# 252  COVID-19-AR-16439200  ...  Lungs are moderately inflated but there are wo...
# 253  COVID-19-AR-16439190  ...  Diffusely distributed throughout the lungs are...
# 254  COVID-19-AR-16445122  ...  Multiple bilateral diffuse peripheral areas of...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
#
# [256 rows x 4 columns]

# %%
DX_data = df[(df.study_modality == 'DX')]

# %%
DX_data
# Out:
# 0              patient_id  ...                           Radiologist_KEY_FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 6    COVID-19-AR-16406513  ...  Patchy, airspace opacities are seen within the...
# 7    COVID-19-AR-16439216  ...                               No relevant findings
# ..                    ...  ...                                                ...
# 251  COVID-19-AR-16439200  ...        Hypoinflated lungs with bibasilar opacities
# 252  COVID-19-AR-16439200  ...  Lungs are moderately inflated but there are wo...
# 253  COVID-19-AR-16439190  ...  Diffusely distributed throughout the lungs are...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
#
# [207 rows x 4 columns]

# %%
DX_data['Image_Study_Description'].value_counts()
# Out:
# XR CHEST AP PORTABLE                             183
# XR CHEST AP ONLY                                  17
# XR CHEST PA AND LATERAL                            3
# XR CHEST PA ONLY                                   2
# XR ACUTE ABDOMINAL SERIES W PA CHEST PORTABLE      2
# Name: Image_Study_Description, dtype: int64

# %%
XR_chest_portable_dataset  = DX_data[(DX_data.Image_Study_Description == 'XR CHEST AP PORTABLE')]
print(XR_chest_portable_dataset.shape)
df['patient_id'].value_counts()
# Out:
# (183, 4)
# COVID-19-AR-16424111    16
# COVID-19-AR-16406531    10
# COVID-19-AR-16439192     7
# COVID-19-AR-16406542     6
# COVID-19-AR-16407183     6
#                         ..
# COVID-19-AR-16445167     1
# COVID-19-AR-16434346     1
# COVID-19-AR-16424077     1
# COVID-19-AR-16434391     1
# COVID-19-AR-16445149     1
# Name: patient_id, Length: 105, dtype: int64

# %%
dataset=pd.read_csv("/content/drive/MyDrive/COVID-19 AR Clinical Correlates July202020_1.csv")
print(dataset.shape)
dataset.head()
# Out:
# (260, 7)
#              Unnamed: 0  ...                                         Unnamed: 6
# 0            patient_id  ...                           Radiologist KEY FINDINGS
# 1  COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2  COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3  COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4  COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
#
# [5 rows x 7 columns]

# %%
dataset.columns=dataset.iloc[0]
dataset=dataset[1:]
dataset
# Out:
# 0              patient_id  ...                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  ...  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  ...  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  ...  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513  ...   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  ...  Mild dependent atelectatic changes are seen in...
# ..                    ...  ...                                                ...
# 255  COVID-19-AR-16445122  ...  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149  ...   Hypoinflated lungs with minimal bibasilar opa...
# 257                   NaN  ...                                                NaN
# 258                   NaN  ...                                                NaN
# 259                   NaN  ...                                                NaN
#
# [259 rows x 7 columns]

# %%
dataset=dataset[['patient_id','Radiologist KEY FINDINGS']]
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  Streaky opacities in bilateral mid and left lo...
# 3    COVID-19-AR-16434381  Lung volumes remain low but there appears to h...
# 4    COVID-19-AR-16406513   patchy increased opacity in the lower lobes b...
# 5    COVID-19-AR-16406513  Mild dependent atelectatic changes are seen in...
# ..                    ...                                                ...
# 255  COVID-19-AR-16445122  Hazy airspace changes are seen in both lung ba...
# 256  COVID-19-AR-16445149   Hypoinflated lungs with minimal bibasilar opa...
# 257                   NaN                                                NaN
# 258                   NaN                                                NaN
# 259                   NaN                                                NaN
#
# [259 rows x 2 columns]

# %%
dataset.dropna(inplace=True)
dataset.shape
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# (256, 2)

# %%
dataset['Radiologist KEY FINDINGS'] = dataset.groupby(['patient_id'])['Radiologist KEY FINDINGS'].transform(lambda x : ' '.join(x))
  
# drop duplicate data
dataset = dataset.drop_duplicates()
dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  Streaky opacities in bilateral mid and left lo...
# 4    COVID-19-AR-16406513   patchy increased opacity in the lower lobes b...
# 7    COVID-19-AR-16439216  No relevant findings Interval development of p...
# 9    COVID-19-AR-16406491  There has been development of bilateral lower ...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  There are bibasilar airspace opacities, left w...
# 251  COVID-19-AR-16439200  Hypoinflated lungs with bibasilar opacities Lu...
# 253  COVID-19-AR-16439190  Diffusely distributed throughout the lungs are...
# 254  COVID-19-AR-16445122  Multiple bilateral diffuse peripheral areas of...
# 256  COVID-19-AR-16445149   Hypoinflated lungs with minimal bibasilar opa...
#
# [105 rows x 2 columns]

# %%
import re

# %%
dataset['Radiologist KEY FINDINGS']=[re.sub(r'[^\w\s]','',data) for data in dataset['Radiologist KEY FINDINGS']]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  Subtle patchy bibasilar and right upper lobe a...
# 2    COVID-19-AR-16434381  Streaky opacities in bilateral mid and left lo...
# 4    COVID-19-AR-16406513   patchy increased opacity in the lower lobes b...
# 7    COVID-19-AR-16439216  No relevant findings Interval development of p...
# 9    COVID-19-AR-16406491  There has been development of bilateral lower ...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  There are bibasilar airspace opacities left wo...
# 251  COVID-19-AR-16439200  Hypoinflated lungs with bibasilar opacities Lu...
# 253  COVID-19-AR-16439190  Diffusely distributed throughout the lungs are...
# 254  COVID-19-AR-16445122  Multiple bilateral diffuse peripheral areas of...
# 256  COVID-19-AR-16445149   Hypoinflated lungs with minimal bibasilar opa...
#
# [105 rows x 2 columns]

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
dataset['Radiologist KEY FINDINGS'] = dataset['Radiologist KEY FINDINGS'].apply(nltk.word_tokenize)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  [Subtle, patchy, bibasilar, and, right, upper,...
# 2    COVID-19-AR-16434381  [Streaky, opacities, in, bilateral, mid, and, ...
# 4    COVID-19-AR-16406513  [patchy, increased, opacity, in, the, lower, l...
# 7    COVID-19-AR-16439216  [No, relevant, findings, Interval, development...
# 9    COVID-19-AR-16406491  [There, has, been, development, of, bilateral,...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  [There, are, bibasilar, airspace, opacities, l...
# 251  COVID-19-AR-16439200  [Hypoinflated, lungs, with, bibasilar, opaciti...
# 253  COVID-19-AR-16439190  [Diffusely, distributed, throughout, the, lung...
# 254  COVID-19-AR-16445122  [Multiple, bilateral, diffuse, peripheral, are...
# 256  COVID-19-AR-16445149  [Hypoinflated, lungs, with, minimal, bibasilar...
#
# [105 rows x 2 columns]

# %%
dataset['Radiologist KEY FINDINGS']= dataset['Radiologist KEY FINDINGS'].apply(lambda x: [i.lower() for i in x ] )
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  [subtle, patchy, bibasilar, and, right, upper,...
# 2    COVID-19-AR-16434381  [streaky, opacities, in, bilateral, mid, and, ...
# 4    COVID-19-AR-16406513  [patchy, increased, opacity, in, the, lower, l...
# 7    COVID-19-AR-16439216  [no, relevant, findings, interval, development...
# 9    COVID-19-AR-16406491  [there, has, been, development, of, bilateral,...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  [there, are, bibasilar, airspace, opacities, l...
# 251  COVID-19-AR-16439200  [hypoinflated, lungs, with, bibasilar, opaciti...
# 253  COVID-19-AR-16439190  [diffusely, distributed, throughout, the, lung...
# 254  COVID-19-AR-16445122  [multiple, bilateral, diffuse, peripheral, are...
# 256  COVID-19-AR-16445149  [hypoinflated, lungs, with, minimal, bibasilar...
#
# [105 rows x 2 columns]

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
def remove_stopwords(text):
    new_wordlist= [i for i in text if i not in stop_words]
    return new_wordlist

# %%
dataset['Radiologist KEY FINDINGS']= dataset['Radiologist KEY FINDINGS'].apply(lambda x:remove_stopwords(x))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  [subtle, patchy, bibasilar, right, upper, lobe...
# 2    COVID-19-AR-16434381  [streaky, opacities, bilateral, mid, left, low...
# 4    COVID-19-AR-16406513  [patchy, increased, opacity, lower, lobes, bil...
# 7    COVID-19-AR-16439216  [relevant, findings, interval, development, pa...
# 9    COVID-19-AR-16406491  [development, bilateral, lower, lobe, airspace...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  [bibasilar, airspace, opacities, left, worse, ...
# 251  COVID-19-AR-16439200  [hypoinflated, lungs, bibasilar, opacities, lu...
# 253  COVID-19-AR-16439190  [diffusely, distributed, throughout, lungs, ar...
# 254  COVID-19-AR-16445122  [multiple, bilateral, diffuse, peripheral, are...
# 256  COVID-19-AR-16445149  [hypoinflated, lungs, minimal, bibasilar, opac...
#
# [105 rows x 2 columns]

# %%
# Lemmatization
from nltk.stem.wordnet import WordNetLemmatizer

lemmatizer  = WordNetLemmatizer()
lemmatized_dataset = []

for this_str in dataset['Radiologist KEY FINDINGS']:
    lemmatized_str = []
    for word in this_str:
        lemmatized_str.append(lemmatizer.lemmatize(word))
    lemmatized_dataset.append(lemmatized_str)

dataset['Radiologist KEY FINDINGS'] = lemmatized_dataset
dataset
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  [subtle, patchy, bibasilar, right, upper, lobe...
# 2    COVID-19-AR-16434381  [streaky, opacity, bilateral, mid, left, lower...
# 4    COVID-19-AR-16406513  [patchy, increased, opacity, lower, lobe, bila...
# 7    COVID-19-AR-16439216  [relevant, finding, interval, development, pat...
# 9    COVID-19-AR-16406491  [development, bilateral, lower, lobe, airspace...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  [bibasilar, airspace, opacity, left, worse, ri...
# 251  COVID-19-AR-16439200  [hypoinflated, lung, bibasilar, opacity, lung,...
# 253  COVID-19-AR-16439190  [diffusely, distributed, throughout, lung, are...
# 254  COVID-19-AR-16445122  [multiple, bilateral, diffuse, peripheral, are...
# 256  COVID-19-AR-16445149  [hypoinflated, lung, minimal, bibasilar, opacity]
#
# [105 rows x 2 columns]

# %%
#word2vec

# %%
from gensim.models import Word2Vec

# %%
bigger_list=list(dataset['Radiologist KEY FINDINGS'])
print(bigger_list)
# Out:
# [['subtle', 'patchy', 'bibasilar', 'right', 'upper', 'lobe', 'airspace', 'opacity'], ['streaky', 'opacity', 'bilateral', 'mid', 'left', 'lower', 'lung', 'patchy', 'opacity', 'right', 'lower', 'lung', 'pleural', 'effusion', 'lung', 'volume', 'remain', 'low', 'appears', 'clearing', 'since', 'prior', 'radiograph'], ['patchy', 'increased', 'opacity', 'lower', 'lobe', 'bilaterally', 'pronounced', 'lateral', 'view', 'small', 'pleural', 'effusion', 'mild', 'dependent', 'atelectatic', 'change', 'seen', 'bilateral', 'upper', 'lobe', 'lower', 'lobe', 'superimposed', 'moderate', 'bilateral', 'lower', 'lobe', 'groundglass', 'consolidative', 'change', 'mild', 'right', 'middle', 'lobe', 'linear', 'atelectasis', 'small', 'groundglass', 'change', 'inferior', 'lingula', 'small', 'consolidation', 'surrounding', 'small', 'groundglass', 'change', 'patchy', 'airspace', 'opacity', 'seen', 'within', 'bilateral', 'lower', 'lung', 'predominantly', 'leftsided', 'haziness', 'left', 'costophrenic', 'angle'], ['relevant', 'finding', 'interval', 'development', 'patchy', 'area', 'consolidation', 'predominately', 'lung', 'base', 'suspicious', 'infection'], ['development', 'bilateral', 'lower', 'lobe', 'airspace', 'disease', 'consistent', 'multilobar', 'pneumonia'], ['patchy', 'groundglass', 'opacity', 'left', 'lung', 'right', 'lower', 'lobe', 'may', 'infectious', 'etiology', 'patchy', 'groundglass', 'change', 'seen', 'within', 'left', 'lung', 'right', 'lower', 'lung', 'significantly', 'changed', 'compared', 'prior', 'study'], ['bilateral', 'patchy', 'airspace', 'disease', 'involving', 'mid', 'lower', 'lung', 'zone', 'left', 'worse', 'right', 'significant', 'worsening', 'airspace', 'disease', 'extensive', 'patchy', 'sparing', 'apex', 'significant', 'worsening', 'bilateral', 'patchy', 'airspace', 'change', 'involving', 'lung', 'zone', 'relative', 'sparing', 'lung', 'apex'], ['bibasilar', 'opacity', 'seen', 'pronounced', 'left', 'large', 'pleural', 'effusion', 'identified', 'left', 'lower', 'lobe', 'airspace', 'disease', 'seen'], ['subtle', 'peribronchovascular', 'opacity', 'noted', 'within', 'lung', 'base', 'somewhat', 'bandlike', 'opacity', 'seen', 'region', 'lateral', 'right', 'upper', 'lung'], ['pleural', 'effusion', 'low', 'lung', 'volume', 'minimal', 'bibasilar', 'subsegmental', 'atelectasis', 'calcified', 'granuloma', 'multiple', 'lung', 'nodule', 'lung', 'volume', 'remain', 'low', 'lung', 'clear', 'evidence', 'acute', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'lung', 'clear', 'without', 'focal', 'consolidation'], ['bibasilar', 'airspace', 'opacity', 'worsening', 'bilateral', 'airspace', 'disease', 'seen', 'within', 'lower', 'lobe'], ['significant', 'airspace', 'consolidation', 'bilaterally', 'lung', 'clear', 'nodule', 'airspace', 'disease', 'pleural', 'effusion', 'right', 'basilar', 'atelectasis'], ['lung', 'free', 'air', 'space', 'disease'], ['focal', 'consolidation', 'lung', 'patchy', 'peripheral', 'groundglass', 'consolidative', 'opacity', 'seen', 'left', 'lung', 'apex', 'right', 'middle', 'lobe', 'bilateral', 'lower', 'lobe', 'focal', 'area', 'round', 'atelectasis', 'seen', 'right', 'lower', 'lobe', 'trace', 'bilateral', 'pleural', 'effusion'], ['subtle', 'patchy', 'airspace', 'disease', 'right', 'lung', 'base', 'diffuse', 'peripheral', 'patchy', 'groundglass', 'opacity', 'seen', 'throughout', 'lung'], ['lung', 'clear', 'well', 'inflated'], ['bibasilar', 'linear', 'opacity', 'may', 'related', 'atelectasis', 'infection', 'interval', 'worsening', 'diffuse', 'opacity', 'throughout', 'lung', 'base'], ['multifocal', 'lower', 'lobe', 'predominant', 'consolidation', 'bilaterally', 'patchy', 'opacity', 'noted', 'lung', 'base', 'greater', 'left', 'right', 'appears', 'slight', 'worsening', 'left', 'change', 'right', 'large', 'effusion', 'noted'], ['lung', 'wellaerated', 'evidence', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'acute', 'airspace', 'change', 'seen', 'lung'], ['indeterminate', '2', 'cm', 'left', 'upper', 'nodule', 'felt', 'repre ...

# %%
# model= Word2Vec(bigger_list,min_count=1,size=300,workers=4)

# %%
 # vocab = list(model.wv.vocab)
# print(vocab)
# print(len(vocab))
# Out:
# ['subtle', 'patchy', 'bibasilar', 'right', 'upper', 'lobe', 'airspace', 'opacity', 'streaky', 'bilateral', 'mid', 'left', 'lower', 'lung', 'pleural', 'effusion', 'volume', 'remain', 'low', 'appears', 'clearing', 'since', 'prior', 'radiograph', 'increased', 'bilaterally', 'pronounced', 'lateral', 'view', 'small', 'mild', 'dependent', 'atelectatic', 'change', 'seen', 'superimposed', 'moderate', 'groundglass', 'consolidative', 'middle', 'linear', 'atelectasis', 'inferior', 'lingula', 'consolidation', 'surrounding', 'within', 'predominantly', 'leftsided', 'haziness', 'costophrenic', 'angle', 'relevant', 'finding', 'interval', 'development', 'area', 'predominately', 'base', 'suspicious', 'infection', 'disease', 'consistent', 'multilobar', 'pneumonia', 'may', 'infectious', 'etiology', 'significantly', 'changed', 'compared', 'study', 'involving', 'zone', 'worse', 'significant', 'worsening', 'extensive', 'sparing', 'apex', 'relative', 'large', 'identified', 'peribronchovascular', 'noted', 'somewhat', 'bandlike', 'region', 'minimal', 'subsegmental', 'calcified', 'granuloma', 'multiple', 'nodule', 'clear', 'evidence', 'acute', 'pneumonic', 'infiltration', 'without', 'focal', 'basilar', 'free', 'air', 'space', 'peripheral', 'round', 'trace', 'diffuse', 'throughout', 'well', 'inflated', 'related', 'multifocal', 'predominant', 'greater', 'slight', 'wellaerated', 'indeterminate', '2', 'cm', 'felt', 'represent', 'hypoinflated', 'slightly', 'improved', 'scattered', 'nodular', 'prominent', 'along', 'interlobular', 'septal', 'thickening', 'side', 'additional', 'persistent', 'perinflated', 'flattened', 'diaphragm', 'suggestive', 'copd', 'versus', 'chronic', 'parenchymal', 'improvement', 'previously', 'pulmonary', 'partially', 'cystic', 'solid', 'pancreatic', 'head', 'mass', 'grossly', 'unchanged', 'infrahilar', 'opacification', 'hazy', 'developing', 'much', 'dense', 'retrocardiac', 'cardiac', 'border', 'increasing', 'andor', 'focus', 'ground', 'glass', 'ncreased', 'midlung', 'appear', 'possible', 'stable', 'illdefined', 'increase', 'predominance', 'perhaps', 'posterior', 'segment', 'size', 'measuring', 'approximately', '18', 'x', '06', '23', 'ap', 'transverse', 'craniocaudal', 'extent', 'examination', 'measured', '17', '07', '22', '3', 'mm', 'new', 'enlarging', 'otherwise', 'also', 'interstitial', 'reticular', 'pattern', '21', '9', '8', 'worsened', 'recent', 'fairly', 'show', 'previous', 'exam', 'residual', 'definite', 'cardiopulmonary', 'lesser', 'mainly', 'near', 'hemidiaphragms', 'conspicuous', 'blunting', 'however', 'spared', 'layering', 'density', 'perihilar', 'early', 'moderatesized', 'pneumothorax', 'infiltrates', 'vascular', 'congestion', 'particularly', 'nonocclusive', 'segmental', 'embolus', 'bifurcation', 'descending', 'artery', 'extending', 'wedgeshaped', 'wedge', 'shaped', 'infiltrative', 'paracardiac', 'sulcus', 'diseaseemphysema', 'aeration', 'possibly', 'periphery', 'partial', 'marked', 'essentially', 'continuing', 'central', 'masslike', '09', 'anterior', 'basal', 'obliteration', 'hemidiaphragm', 'interface', 'fully', 'resolved', 'appearance', 'chest', 'symmetric', 'aspect', 'clinical', 'concern', 'ards', 'comparison', 'prominence', 'lingulaleft', 'largely', 'little', 'overall', 'still', 'decrease', 'portion', 'faint', 'heart', 'confluent', 'evident', 'persist', 'minimally', 'distribution', 'emphysema', 'rightsided', 'subcutaneous', 'wall', 'subpleural', 'honeycombing', 'groundglassconsolidative', 'sided', 'demonstrate', 'present', 'fluid', 'cp', 'indicative', 'underinflated', 'likely', 'mildly', 'question', 'probable', 'improving', 'effusionspleural', 'demonstrated', 'moderately', 'diffusely', 'distributed']
# 313

# %%
# vectors=model.fit_transform(dataset['Radiologist KEY FINDINGS'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-108b6e0d7571> in <module>()
# ----> 1 vectors=model.fit_transform(dataset['Radiologist KEY FINDINGS'])
#
# AttributeError: 'Word2Vec' object has no attribute 'fit_transform'

# %%
# similar_words = model.most_similar('opacity')	
# print(similar_words)
# Out:
# [('lung', 0.8447763919830322), ('airspace', 0.8295207023620605), ('pleural', 0.7955666184425354), ('disease', 0.7926300764083862), ('left', 0.7877292633056641), ('right', 0.7777352929115295), ('lobe', 0.7702904939651489), ('bilateral', 0.766097903251648), ('seen', 0.7505060434341431), ('diffuse', 0.7472540140151978)]
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.

# %%
# from sklearn.preprocessing import OneHotEncoder
# enc = OneHotEncoder(handle_unknown='ignore')
# enc.fit(bigger_list)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:746: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   array = np.asarray(array, order=order, dtype=dtype)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-5e5a4a353467> in <module>()
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 enc = OneHotEncoder(handle_unknown='ignore')
# ----> 3 enc.fit(bigger_list)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_encoders.py in fit(self, X, y)
#     459         """
#     460         self._validate_keywords()
# --> 461         self._fit(X, handle_unknown=self.handle_unknown, force_all_finite="allow-nan")
#     462         self.drop_idx_ = self._compute_drop_idx()
#     463         return self
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_encoders.py in _fit(self, X, handle_unknown, force_all_finite)
#      76         self._check_feature_names(X, reset=True)
#      77         X_list, n_samples, n_features = self._check_X(
# ---> 78             X, force_all_finite=force_all_finite
#      79         )
#      80         self.n_features_in_ = n_features
#
# /usr/local/lib/python3.7/dist-packages/sklearn/preprocessing/_encoders.py in _check_X(self, X, force_all_finite)
#      42         if not (hasattr(X, "iloc") and getattr(X, "ndim", 0) == 2):
#      43             # if not a dataframe, do normal check_array validation
# ---> 44             X_temp = check_array(X, dtype=None, force_all_finite=force_all_finite)
#      45             if not hasattr(X, "dtype") and np.issubdtype(X_temp.dtype, np.str_):
#      46                 X = check_array(X, dtype=object, force_all_finite=force_all_finite)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     771                     "Reshape your data either using array.reshape(-1, 1) if "
#     772                     "your data has a single feature or array.reshape(1, -1) "
# --> 773                     "if it contains a single sample.".format(array)
#     774                 )
#     775
#
# ValueError: Expected 2D array, got 1D array instead:
# array=[list(['subtle', 'patchy', 'bibasilar', 'right', 'upper', 'lobe', 'airspace', 'opacity'])
#  list(['streaky', 'opacity', 'bilateral', 'mid', 'left', 'lower', 'lung', 'patchy', 'opacity', 'right', 'lower', 'lung', 'pleural', 'effusion', 'lung', 'volume', 'remain', 'low', 'appears', 'clearing', 'since', 'prior', 'radiograph'])
#  list(['patchy', 'increased', 'opacity', 'lower', 'lobe', 'bilaterally', 'pronounced', 'lateral', 'view', 'small', 'pleural', 'effusion', 'mild', 'dependent', 'atelectatic', 'change', 'seen', 'bilateral', 'upper', 'lobe', 'lower', 'lobe', 'superimposed', 'moderate', 'bilateral', 'lower', 'lobe', 'groundglass', 'consolidative', 'change', 'mild', 'right', 'middle', 'lobe', 'linear', 'atelectasis', 'small', 'groundglass', 'change', 'inferior', 'lingula', 'small', 'consolidation', 'surrounding', 'small', 'groundglass', 'change', 'patchy', 'airspace', 'opacity', 'seen', 'within', 'bilateral', 'lower', 'lung', 'predominantly', 'leftsided', 'haziness', 'left', 'costophrenic', 'angle'])
#  list(['relevant', 'finding', 'interval', 'development', 'patchy', 'area', 'consolidation', 'predominately', 'lung', 'base', 'suspicious', 'infection'])
#  list(['development', 'bilateral', 'lower', 'lobe', 'airspace', 'disease', 'consistent', 'multilobar', 'pneumonia'])
#  list(['patchy', 'groundglass', 'opacity', 'left', 'lung', 'right', 'lower', 'lobe', 'may', 'infectious', 'etiology', 'patchy', 'groundglass', 'change', 'seen', 'within', 'left', 'lung', 'right', 'lower', 'lung', 'significantly', 'changed', 'compared', 'prior', 'study'])
#  list(['bilateral', 'patchy', 'airspace', 'disease', 'involving', 'mid', 'lower', 'lung', 'zone', 'left', 'worse', 'right', 'significant', 'worsening', 'airspace', 'disease', 'extensive', 'patchy', 'sparing', 'apex', 'significant', 'worsening', 'bilateral', 'patchy', 'airspace', 'change', 'involving', 'lung', 'zone', 'relative', 'sparing', 'lung', 'apex'])
#  list(['bibasilar', 'opacity', 'seen', 'pronounced', 'left', 'large', 'pleural', 'effusion', 'identified', 'left', 'lower', 'lobe', 'airspace', 'disease', 'seen'])
#  list(['subtle', 'peribronchovascular', 'opacity', 'noted', 'within', 'lung', 'base', 'somewhat', 'bandlike', 'opacity', 'seen', 'region', 'lateral', 'right', 'upper', 'lung'])
#  list(['pleural', 'effusion', 'low', 'lung', 'volume', 'minimal', 'bibasilar', 'subsegmental', 'atelectasis', 'calcified', 'granuloma', 'multiple', 'lung', 'nodule', 'lung', 'volume', 'remain', 'low', 'lung', 'clear', 'evidence', 'acute', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['bibasilar', 'airspace', 'opacity', 'worsening', 'bilateral', 'airspace', 'disease', 'seen', 'within', 'lower', 'lobe'])
#  list(['significant', 'airspace', 'consolidation', 'bilaterally', 'lung', 'clear', 'nodule', 'airspace', 'disease', 'pleural', 'effusion', 'right', 'basilar', 'atelectasis'])
#  list(['lung', 'free', 'air', 'space', 'disease'])
#  list(['focal', 'consolidation', 'lung', 'patchy', 'peripheral', 'groundglass', 'consolidative', 'opacity', 'seen', 'left', 'lung', 'apex', 'right', 'middle', 'lobe', 'bilateral', 'lower', 'lobe', 'focal', 'area', 'round', 'atelectasis', 'seen', 'right', 'lower', 'lobe', 'trace', 'bilateral', 'pleural', 'effusion'])
#  list(['subtle', 'patchy', 'airspace', 'disease', 'right', 'lung', 'base', 'diffuse', 'peripheral', 'patchy', 'groundglass', 'opacity', 'seen', 'throughout', 'lung'])
#  list(['lung', 'clear', 'well', 'inflated'])
#  list(['bibasilar', 'linear', 'opacity', 'may', 'related', 'atelectasis', 'infection', 'interval', 'worsening', 'diffuse', 'opacity', 'throughout', 'lung', 'base'])
#  list(['multifocal', 'lower', 'lobe', 'predominant', 'consolidation', 'bilaterally', 'patchy', 'opacity', 'noted', 'lung', 'base', 'greater', 'left', 'right', 'appears', 'slight', 'worsening', 'left', 'change', 'right', 'large', 'effusion', 'noted'])
#  list(['lung', 'wellaerated', 'evidence', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'acute', 'airspace', 'change', 'seen', 'lung'])
#  list(['indeterminate', '2', 'cm', 'left', 'upper', 'nodule', 'felt', 'represent', 'calcified', 'granuloma', 'subtle', 'airspace', 'opacity', 'right', 'upper', 'lobe'])
#  list(['lung', 'hypoinflated', 'worsening', 'bibasilar', 'opacity', 'mild', 'bibasilar', 'airspace', 'disease', 'slightly', 'improved', 'right'])
#  list(['small', 'bilateral', 'effusion', 'scattered', 'area', 'groundglass', 'nodular', 'opacity', 'seen', 'within', 'lung', 'prominent', 'within', 'basilar', 'lower', 'lobe', 'along', 'area', 'interlobular', 'septal', 'thickening', 'acute', 'disease', 'subtle', 'bibasilar', 'opacity', 'noted'])
#  list(['groundglass', 'opacity', 'bilateral', 'lower', 'lobe', 'slightly', 'pronounced', 'right', 'side', 'additional', 'right', 'lung', 'base'])
#  list(['persistent', 'trace', 'left', 'pleural', 'effusion', 'perinflated', 'lung', 'flattened', 'diaphragm', 'suggestive', 'copd', 'subtle', 'airspace', 'disease', 'versus', 'chronic', 'parenchymal', 'change', 'along', 'left', 'lung', 'base', 'improvement', 'previously', 'seen', 'pulmonary', 'opacity', 'trace', 'nodular', 'groundglass', 'opacity', 'lingula', 'left', 'lower', 'lobe', 'previously', 'seen', 'partially', 'cystic', 'partially', 'solid', 'pancreatic', 'head', 'mass', 'grossly', 'unchanged'])
#  list(['interval', 'development', 'right', 'infrahilar', 'opacity', 'lung', 'clear', 'without', 'focal', 'airspace', 'opacification'])
#  list(['patchy', 'bibasilar', 'opacity', 'bibasilar', 'atelectasis', 'low', 'lung', 'volume'])
#  list(['subtle', 'hazy', 'opacity', 'bilateral', 'lung', 'base', 'lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['subtle', 'airspace', 'disease', 'developing', 'left', 'lower', 'lobe'])
#  list(['hazy', 'airspace', 'opacity', 'seen', 'throughout', 'bilateral', 'lower', 'lung', 'right', 'greater', 'left', 'worsening', 'bilateral', 'lower', 'lobe', 'opacity', 'consistent', 'airspace', 'disease', 'much', 'dense', 'retrocardiac', 'left', 'lower', 'lobe', 'consistent', 'consolidation'])
#  list(['haziness', 'left', 'cardiac', 'border', 'increasing', 'airspace', 'opacity', 'right', 'upper', 'lobe', 'increased', 'left', 'pleural', 'effusion', 'consolidation', 'andor', 'atelectasis', 'left', 'lower', 'lobe'])
#  list(['subtle', 'hazy', 'opacity', 'lung', 'base'])
#  list(['scattered', 'focus', 'ground', 'glass', 'opacity', 'lobe', 'lung', 'right', 'upper', 'lobe', 'atelectasis', 'ncreased', 'bilateral', 'lower', 'lung', 'right', 'midlung', 'airspace', 'opacity'])
#  list(['acute', 'disease', 'focal', 'pneumonia'])
#  list(['lung', 'appear', 'clear', 'without', 'focal', 'consolidation'])
#  list(['diffuse', 'bibasilar', 'haziness', 'possible', 'trace', 'pleural', 'effusion', 'stable', 'hazy', 'illdefined', 'airspace', 'opacity', 'throughout', 'lung', 'slight', 'increase', 'illdefined', 'hazy', 'airspace', 'opacification', 'throughout', 'bilateral', 'lung', 'subtle', 'lower', 'lobe', 'predominance', 'persistent', 'bilateral', 'airspace', 'disease', 'perhaps', 'slight', 'improvement'])
#  list(['lung', 'clear', 'lung', 'clear', 'without', 'acute', 'airspace', 'disease', 'significant', 'pleural', 'effusion', 'acute', 'consolidation', 'linear', 'opacity', 'within', 'posterior', 'segment', 'right', 'upper', 'lobe', 'significantly', 'changed', 'size', 'measuring', 'approximately', '18', 'x', '06', 'x', '23', 'cm', 'ap', 'transverse', 'craniocaudal', 'extent', 'significantly', 'changed', 'prior', 'examination', 'measured', '17', 'x', '07', 'x', '22', 'cm', '3', 'mm', 'nodule', 'within', 'left', 'lung', 'apex', 'unchanged', 'prior', 'examination', 'new', 'enlarging', 'lung', 'nodule', 'identified'])
#  list(['right', 'lung', 'low', 'volume', 'otherwise', 'clear', 'significant', 'consolidation', 'also', 'interval', 'improvement', 'left', 'retrocardiac', 'airspace', 'disease', 'peribronchovascular', 'change', 'noted', 'interval', 'development', 'minimal', 'peribronchovascular', 'airspace', 'disease', 'right', 'upper', 'lobe', 'trace', 'peribronchovascular', 'airspace', 'disease', 'noted', 'within', 'right', 'upper', 'lobe', 'otherwise', 'lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['mild', 'diffuse', 'interstitial', 'reticular', 'pattern', 'throughout', 'lung'])
#  list(['lung', 'appear', 'clear', 'nodule', 'airspace', 'consolidation', 'pleural', 'effusion', '21', 'cm', 'groundglass', 'nodule', 'posterior', 'right', 'upper', 'lobe', '9', 'mm', 'groundglass', 'nodule', 'posterior', 'right', 'lower', 'lobe', '8', 'mm', 'groundglass', 'nodule', 'posterior', 'left', 'upper', 'lobe'])
#  list(['lung', 'free', 'air', 'space', 'disease'])
#  list(['subtle', 'hazy', 'opacity', 'noted', 'predominantly', 'within', 'lung', 'base', 'diffuse', 'bilateral', 'peribronchovascular', 'opacity', 'throughout', 'lung', 'worsened', 'since', 'recent', 'prior', 'fairly', 'diffuse', 'airspace', 'disease', 'throughout', 'lung', 'show', 'improvement', 'illdefined', 'peripheral', 'airspace', 'opacity', 'appear', 'improved', 'compared', 'prior', 'study', 'bibasilar', 'consolidation', 'andor', 'atelectasis', 'small', 'left', 'pleural', 'effusion', 'increased', 'previous', 'exam', 'residual', 'illdefined', 'bibasilar', 'opacity', 'significantly', 'changed'])
#  list(['definite', 'acute', 'cardiopulmonary', 'finding'])
#  list(['focal', 'consolidation', 'pleural', 'effusion', 'subtle', 'bibasilar', 'airspace', 'opacity', 'bilateral', 'lower', 'lung', 'atelectatic', 'change', 'mild', 'superimposed', 'bilateral', 'lower', 'lung', 'illdefined', 'airspace', 'opacity', 'significantly', 'changed'])
#  list(['patchy', 'airspace', 'opacity', 'within', 'left', 'lower', 'lobe', 'lesser', 'extent', 'within', 'right', 'lower', 'lobe', 'mild', 'bibasilar', 'airspace', 'disease', 'significantly', 'changed', 'prior', 'streaky', 'opacity', 'mainly', 'lung', 'base', 'near', 'hemidiaphragms', 'increased', 'somewhat', 'patchy', 'opacity', 'seen', 'lung', 'base', 'conspicuous', 'compared', 'prior', 'study', 'stable', 'bibasilar', 'streaky', 'opacity', 'noted', 'interval', 'blunting', 'bilateral', 'costophrenic', 'angle'])
#  list(['evidence', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'hazy', 'opacity', 'within', 'right', 'lung', 'base', 'lesser', 'extent', 'within', 'left', 'lung', 'base'])
#  list(['multiple', 'patchy', 'illdefined', 'airspace', 'opacity', 'bilaterally', 'worsening', 'somewhat', 'diffuse', 'airspace', 'disease', 'airspace', 'disease', 'increased', 'right', 'upper', 'lobe', 'left', 'upper', 'lobe', 'however', 'spared', 'persistent', 'airspace', 'disease', 'seen', 'lower', 'lobe', 'diffuse', 'opacity', 'noted', 'may', 'small', 'layering', 'pleural', 'effusion'])
#  list(['bilateral', 'peripheral', 'groundglass', 'change', 'bilateral', 'lower', 'lung', 'atelectasis', 'bibasilar', 'opacity'])
#  list(['lung', 'hypoinflated', 'bibasilar', 'airspace', 'opacity'])
#  list(['interval', 'development', 'right', 'pleural', 'effusion', 'bibasilar', 'linear', 'opacity', 'blunting', 'left', 'costophrenic', 'angle', 'suggestive', 'small', 'pleural', 'effusion'])
#  list(['illdefined', 'density', 'lung', 'base', 'left', 'greater', 'right', 'clearing', 'previous', 'illdefined', 'opacity', 'lung', 'base'])
#  list(['increased', 'patchy', 'opacity', 'throughout', 'lung', 'bilaterally', 'subtle', 'perihilar', 'hazy', 'opacity', 'noted', 'bilaterally', 'consistent', 'early', 'airspace', 'disease', 'dense', 'consolidation', 'significant', 'worsening', 'multifocal', 'infection', 'involving', 'lung', 'patchy', 'airspace', 'opacity', 'throughout', 'lung', 'without', 'significant', 'change', 'interval', 'development', 'moderatesized', 'right', 'pneumothorax', 'stable', 'patchy', 'opacity', 'throughout', 'lung', 'stable', 'patchy', 'opacity', 'throughout', 'lung', 'improvement', 'diffuse', 'bilateral', 'patchy', 'infiltrates'])
#  list(['lung', 'well', 'inflated', 'clear', 'nodule', 'airspace', 'disease', 'pleural', 'effusion', 'significant', 'pleural', 'effusion', 'acute', 'consolidation'])
#  list(['pleural', 'effusion', 'pneumothorax', 'consolidation', 'focal', 'airspace', 'opacification', 'pleural', 'effusion', 'significant', 'evidence', 'pulmonary', 'vascular', 'congestion'])
#  list(['bilateral', 'peribronchovascular', 'groundglass', 'opacity', 'particularly', 'within', 'upper', 'lung', 'trace', 'bilateral', 'pleural', 'effusion', 'mild', 'bibasilar', 'opacity', 'peribronchovascular', 'opacity', 'right', 'upper', 'lobe'])
#  list(['lung', 'appear', 'clear', 'evidence', 'airspace', 'consolidation', 'lung', 'clear', 'without', 'evidence', 'focal', 'consolidation'])
#  list(['nonocclusive', 'segmental', 'pulmonary', 'embolus', 'bilaterally', 'bifurcation', 'right', 'descending', 'pulmonary', 'artery', 'extending', 'right', 'upper', 'middle', 'lower', 'lobe', 'wedgeshaped', 'airspace', 'opacity', 'right', 'upper', 'middle', 'lobe', 'lingula', 'diffuse', 'peripheral', 'airspace', 'opacity', 'bilaterally', 'right', 'worse', 'left', 'wedge', 'shaped', 'opacity', 'right', 'middle', 'lobe'])
#  list(['lung', 'clear', 'without', 'focal', 'consolidation', 'subtle', 'increased', 'perihilar', 'hazy', 'airspace', 'opacity', 'bilaterally', 'patchy', 'lung', 'opacity', 'noted', 'bilaterally', 'slightly', 'increased', 'prior', 'examination'])
#  list(['atelectatic', 'infiltrative', 'change', 'left', 'retrocardiac', 'paracardiac', 'region', 'blunting', 'costophrenic', 'sulcus', 'slightly', 'increased', 'consolidation', 'left', 'lower', 'lobe', 'scattered', 'patchy', 'airspace', 'opacity', 'linear', 'atelectatic', 'change', 'lung', 'grossly', 'unchanged'])
#  list(['mild', 'bibasilar', 'atelectasis', 'left', 'greater', 'right', 'groundglass', 'opacity', 'focal', 'consolidation', 'pleural', 'effusion'])
#  list(['lung', 'wellaerated', 'evidence', 'pneumonic', 'infiltration', 'pleural', 'effusion', 'lung', 'clear', 'without', 'focal', 'airspace', 'opacification'])
#  list(['chronic', 'lung', 'diseaseemphysema', 'noted', 'multifocal', 'airspace', 'opacity', 'noted', 'throughout', 'lung', 'persistent', 'consolidation', 'right', 'upper', 'lobe', 'small', 'bilateral', 'pleural', 'effusion', 'interval', 'improved', 'aeration', 'previous', 'exam', 'patchy', 'opacity', 'throughout', 'right', 'upper', 'mid', 'bilateral', 'lower', 'lung', 'patchy', 'lung', 'opacity', 'noted', 'bilaterally', 'possibly', 'increased', 'within', 'right', 'lung', 'base'])
#  list(['lung', 'clear', 'focal', 'airspace', 'disease'])
#  list(['streaky', 'opacity', 'lung', 'base'])
#  list(['patchy', 'infiltrates', 'lung', 'mainly', 'periphery', 'bilaterally'])
#  list(['lung', 'clear'])
#  list(['interval', 'development', 'diffuse', 'bilateral', 'airspace', 'disease', 'partial', 'sparing', 'left', 'lung', 'apex', 'diffuse', 'patchy', 'airspace', 'disease', 'lung', 'marked', 'improvement', 'previous', 'bilateral', 'airspace', 'disease', 'minimal', 'residual', 'left', 'base', 'right', 'lung', 'essentially', 'clear', 'illdefined', 'airspace', 'disease', 'continuing', 'lung', 'base', 'mainly', 'lower', 'lobe', 'right', 'perihilar', 'region', 'airspace', 'opacity', 'worsened', 'slightly', 'interval', 'illdefined', 'bilateral', 'airspace', 'opacity', 'within', 'central', 'mid', 'lower', 'lung', 'focal', 'masslike', 'airspace', 'opacification', 'posterior', 'segment', 'right', 'upper', 'lobe', '09', 'cm', 'nodule', 'anterior', 'segment', 'right', 'upper', 'lobe', 'pleural', 'effusion', 'consolidation', 'left', 'lower', 'lobe', 'predominantly', 'involving', 'posterior', 'basal', 'lateral', 'basal', 'segment'])
#  list(['atelectatic', 'change', 'seen', 'right', 'lung', 'base', 'left', 'diffuse', 'haziness', 'partial', 'obliteration', 'left', 'hemidiaphragm', 'interface', 'left', 'lower', 'lobe', 'opacity', 'improved', 'fully', 'resolved', 'minimal', 'right', 'infrahilar', 'opacity'])
#  list(['lung', 'well', 'inflated', 'clear']) list(['lung', 'clear'])
#  list(['patchy', 'airspace', 'opacity', 'groundglass', 'change', 'seen', 'upper', 'lobe', 'lung', 'well', 'right', 'lower', 'lobe', 'left', 'lower', 'lobe', 'patchy', 'airspace', 'opacity', 'seen', 'lung', 'involving', 'right', 'upper', 'right', 'lower', 'lobe', 'left', 'lower', 'lobe'])
#  list(['lung', 'free', 'air', 'space', 'disease', 'patchy', 'slightly', 'worsened', 'airspace', 'opacity', 'predominately', 'lung', 'base', 'increased', 'diffuse', 'haziness', 'consistent', 'airspace', 'disease'])
#  list(['lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['patchy', 'airspace', 'opacity', 'bilateral', 'lung', 'base', 'right', 'greater', 'left'])
#  list(['stable', 'appearance', 'chest', 'acute', 'disease'])
#  list(['increased', 'interstitial', 'change', 'lung', 'symmetric', 'worsening', 'patchy', 'airspace', 'opacity', 'seen', 'throughout', 'bilateral', 'lung', 'predominantly', 'within', 'lateral', 'aspect', 'left', 'lower', 'lung', 'worsening', 'diffuse', 'airspace', 'disease', 'noted', 'throughout', 'lung', 'interval', 'worsening', 'diffuse', 'bilateral', 'multifocal', 'pneumonia', 'diffuse', 'haziness', 'lung', 'consistent', 'clinical', 'concern', 'ards', 'change', 'right', 'worse', 'comparison', 'left', 'significant', 'change', 'bilateral', 'airspace', 'opacity', 'interstitial', 'prominence', 'prior', 'study', 'persistent', 'perhaps', 'somewhat', 'diffuse', 'bilateral', 'airspace', 'disease', 'multifocal', 'consolidation', 'atelectasis', 'significantly', 'involving', 'lingulaleft', 'lower', 'lobe', 'small', 'left', 'pleural', 'effusion', 'extensive', 'airspace', 'disease', 'throughout', 'lung', 'show', 'improvement', 'largely', 'unchanged', 'extensive', 'bilateral', 'airspace', 'opacity', 'diffuse', 'multifocal', 'consolidation', 'involving', 'lung', 'seen', 'worsened'])
#  list(['lung', 'clear'])
#  list(['diffuse', 'opacity', 'bilateral', 'lung', 'base', 'patchy', 'illdefined', 'airspace', 'disease', 'lung', 'base', 'little', 'changed', 'persistent', 'bibasilar', 'opacity', 'consistent', 'somewhat', 'worse', 'left', 'right', 'overall', 'little', 'change'])
#  list(['patchy', 'area', 'illdefined', 'consolidation', 'lower', 'lobe', 'upper', 'lung', 'still', 'clear', 'interval', 'decrease', 'aeration', 'lung', 'stable', 'worsening', 'bilateral', 'lower', 'lobe', 'peribronchovascular', 'airspace', 'disease', 'minimal', 'interval', 'improvement', 'patchy', 'bilateral', 'airspace', 'opacity', 'mild', 'bibasilar', 'atelectasis', 'patchy', 'lung', 'opacity', 'bilaterally', 'changed', 'significantly', 'worsening', 'patchy', 'area', 'consolidation', 'mid', 'upper', 'portion', 'right', 'lung', 'lesser', 'extent', 'lower', 'left', 'lung'])
#  list(['faint', 'airspace', 'opacity', 'left', 'mid', 'lung', 'along', 'left', 'heart', 'border', 'worsening', 'consolidation', 'noted', 'lower', 'lobe', 'mid', 'right', 'lung', 'region'])
#  list(['low', 'lung', 'volume', 'bibasilar', 'atelectatic', 'change', 'significant', 'interval', 'worsening', 'bilateral', 'mid', 'lower', 'lung', 'confluent', 'peripheral', 'airspace', 'opacity'])
#  list(['significant', 'airspace', 'consolidation', 'evident', 'bilaterally', 'trace', 'right', 'basilar', 'opacity', 'felt', 'represent', 'atelectatic', 'change'])
#  list(['subtle', 'streaky', 'opacity', 'left', 'lung', 'base', 'slightly', 'increased', 'interstitial', 'opacity', 'noted', 'bilaterally', 'opacity', 'within', 'right', 'mid', 'lung', 'base', 'persist', 'improved', 'prior', 'examination', 'persistent', 'airspace', 'disease', 'within', 'left', 'mid', 'lung', 'persistent', 'minimally', 'improved', 'airspace', 'disease', 'within', 'left', 'mid', 'lower', 'lung', 'airspace', 'disease', 'left', 'mid', 'lung', 'appears', 'largely', 'unchanged'])
#  list(['focal', 'area', 'consolidation', 'within', 'right', 'lower', 'lobe', 'marked', 'interval', 'worsening', 'multifocal', 'airspace', 'disease', 'throughout', 'lung', 'somewhat', 'patchy', 'density', 'distribution', 'little', 'change', 'diffuse', 'bilateral', 'airspace', 'disease', 'worsening', 'consolidative', 'change', 'mid', 'lower', 'lung', 'zone', 'minimal', 'bilateral', 'pleural', 'effusion'])
#  list(['upper', 'lobe', 'predominant', 'emphysema', 'lung', 'appear', 'clear', 'evidence', 'airspace', 'consolidation', 'lung', 'remain', 'clear', 'pleural', 'effusion', 'small', 'rightsided', 'pneumothorax', 'subcutaneous', 'emphysema', 'right', 'lateral', 'chest', 'wall', 'left', 'lower', 'lobe', 'atelectasis', 'focal', 'airspace', 'opacification', 'pleural', 'effusion', 'mild', 'atelectatic', 'change', 'right', 'lung', 'base', 'focal', 'consolidation', 'left', 'lung', 'appears', 'clear'])
#  list(['diffuse', 'hazy', 'lung', 'opacity', 'bilaterally', 'significant', 'within', 'right', 'perihilar', 'region', 'bilateral', 'lung', 'base', 'worsening', 'bilateral', 'airspace', 'disease', 'predominately', 'perihilar', 'region', 'mid', 'left', 'lung'])
#  list(['lung', 'slightly', 'hypoinflated', 'left', 'basilar', 'atelectasis', 'right', 'lung', 'predominantly', 'clear', 'worsening', 'patchy', 'multifocal', 'airspace', 'opacity', 'mainly', 'mid', 'lower', 'lung', 'bilaterally', 'groundglass', 'opacity', 'right', 'upper', 'lobe', 'subpleural', 'reticular', 'opacity', 'honeycombing'])
#  list(['lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['subtle', 'hazy', 'opacity', 'left', 'lower', 'lobe', 'consistent', 'groundglass', 'airspace', 'disease', 'minimal', 'right', 'infrahilar', 'airspace', 'opacity', 'slight', 'hazy', 'right', 'perihilar', 'opacity'])
#  list(['lung', 'clear'])
#  list(['mild', 'bibasilar', 'airspace', 'opacity'])
#  list(['dense', 'consolidation', 'pleural', 'effusion', 'lung', 'appear', 'clear'])
#  list(['atelectatic', 'change', 'lung', 'base'])
#  list(['focal', 'airspace', 'consolidation', 'pleural', 'effusion'])
#  list(['lung', 'clear', 'without', 'focal', 'consolidation'])
#  list(['lung', 'clear', 'nodule', 'airspace', 'disease', 'pleural', 'effusion', 'peripheral', 'patchy', 'opacity', 'mid', 'lung', 'predominance', 'bilateral', 'lung', 'worsened', 'diffuse', 'bilateral', 'mainly', 'peripheral', 'infiltrates', 'involving', 'lung'])
#  list(['patchy', 'bilateral', 'groundglassconsolidative', 'opacity', 'seen', 'bilateral', 'lung', 'base', 'patchy', 'peripheral', 'groundglass', 'opacity', 'inferior', 'aspect', 'bilateral', 'upper', 'lobe', 'bilateral', 'lower', 'lobe', 'patchy', 'consolidative', 'airspace', 'opacity', 'posterior', 'lower', 'lobe', 'bilaterally', 'patchy', 'opacity', 'throughout', 'lung', 'significantly', 'changed', 'prior', 'examination', 'essentially', 'stable', 'bilateral', 'patchy', 'groundglass', 'consolidative', 'opacity', 'throughout', 'lung'])
#  list(['lung', 'clear', 'without', 'evidence', 'focal', 'consolidation'])
#  list(['minimal', 'right', 'sided', 'effusion', 'right', 'basilar', 'atelectasis', 'atelectasis', 'pleural', 'effusion', 'right', 'acute', 'airspace', 'change', 'left', 'lung', 'demonstrate', 'moderate', 'right', 'small', 'left', 'pleural', 'effusion', 'small', 'rightsided', 'pneumothorax', 'streaky', 'consolidation', 'still', 'present', 'lung', 'base', 'without', 'improvement', 'may', 'residual', 'pleural', 'fluid', 'mainly', 'right', 'side', 'without', 'worsening', 'evidence', 'bibasilar', 'atelectasis', 'also', 'blunting', 'cp', 'angle', 'indicative', 'small', 'effusion', 'lung', 'underinflated', 'patchy', 'streaky', 'airspace', 'opacity', 'along', 'lung', 'base', 'mid', 'right', 'lung', 'region', 'patchy', 'bibasilar', 'opacity', 'seen', 'likely', 'atelectasis', 'change', 'small', 'right', 'pleural', 'effusion', 'seen', 'right', 'lower', 'lobe', 'atelectasis', 'pneumothorax', 'seen', 'left', 'basilar', 'atelectasis', 'seen', 'linear', 'opacity', 'seen', 'within', 'bilateral', 'lung', 'base', 'small', 'rightsided', 'pleural', 'effusion', 'mildly', 'worsened', 'right', 'lung', 'base', 'airspace', 'opacity', 'unchanged', 'left', 'lung', 'base', 'atelectasis', 'bilateral', 'lower', 'lung', 'atelectatic', 'change', 'question', 'superimposed', 'airspace', 'opacity', 'side', 'mildly', 'improved', 'persistent', 'linear', 'atelectasis', 'seen', 'within', 'bilateral', 'lung', 'base', 'probable', 'small', 'bilateral', 'pleural', 'effusion', 'persistent', 'bibasilar', 'atelectatic...
#  list(['confluent', 'bilateral', 'airspace', 'opacity', 'mid', 'lower', 'lung', 'predominance', 'prominent', 'left', 'right', 'represent', 'multifocal', 'infection'])
#  list(['illdefined', 'left', 'lower', 'lung', 'airspace', 'opacity', 'illdefined', 'bilateral', 'lower', 'lung', 'airspace', 'opacity', 'demonstrated', 'mildly', 'worsened', 'exam', 'scattered', 'small', 'peripheral', 'groundglass', 'opacity', 'anterior', 'lateral', 'segment', 'right', 'upper', 'lobe', 'right', 'lower', 'lobe', 'hazy', 'opacity', 'within', 'bilateral', 'lung', 'base'])
#  list(['bibasilar', 'airspace', 'opacity', 'left', 'worse', 'right', 'interval', 'worsening', 'airspace', 'opacity', 'lung', 'mild', 'bilateral', 'pleural', 'effusion', 'interval', 'improvement', 'somewhat', 'confluent', 'diffuse', 'airspace', 'opacity', 'throughout', 'lung', 'stable', 'patchy', 'airspace', 'opacity', 'throughout', 'bilateral', 'lung', 'multiple', 'predominately', 'peripheral', 'infiltrates', 'seen', 'throughout', 'lung', 'somewhat', 'extensive', 'right', 'lung', 'compared', 'left'])
#  list(['hypoinflated', 'lung', 'bibasilar', 'opacity', 'lung', 'moderately', 'inflated', 'worsening', 'illdefined', 'infiltrates', 'predominately', 'periphery', 'lung'])
#  list(['diffusely', 'distributed', 'throughout', 'lung', 'area', 'consolidation', 'groundglass', 'change'])
#  list(['multiple', 'bilateral', 'diffuse', 'peripheral', 'area', 'nodular', 'groundglass', 'consolidation', 'seen', 'involving', 'lobe', 'pronounced', 'lung', 'base', 'hazy', 'airspace', 'change', 'seen', 'lung', 'base', 'evidence', 'consolidation'])
#  list(['hypoinflated', 'lung', 'minimal', 'bibasilar', 'opacity'])].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.

# %%
dataset["Radiologist KEY FINDINGS"]= dataset["Radiologist KEY FINDINGS"].str.join(" ")
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
dataset
# Out:
# 0              patient_id                           Radiologist KEY FINDINGS
# 1    COVID-19-AR-16434409  subtle patchy bibasilar right upper lobe airsp...
# 2    COVID-19-AR-16434381  streaky opacity bilateral mid left lower lung ...
# 4    COVID-19-AR-16406513  patchy increased opacity lower lobe bilaterall...
# 7    COVID-19-AR-16439216  relevant finding interval development patchy a...
# 9    COVID-19-AR-16406491  development bilateral lower lobe airspace dise...
# ..                    ...                                                ...
# 246  COVID-19-AR-16434383  bibasilar airspace opacity left worse right in...
# 251  COVID-19-AR-16439200  hypoinflated lung bibasilar opacity lung moder...
# 253  COVID-19-AR-16439190  diffusely distributed throughout lung area con...
# 254  COVID-19-AR-16445122  multiple bilateral diffuse peripheral area nod...
# 256  COVID-19-AR-16445149        hypoinflated lung minimal bibasilar opacity
#
# [105 rows x 2 columns]

# %%
dataset['Radiologist KEY FINDINGS'].value_counts()
# Out:
# lung clear                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          4
# lung clear without focal consolidation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              3
# lung free air space disease                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         2
# patchy infiltrates lung mainly periphery bilaterally                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                1
# increased interstitial change lung symmetric worsening patchy airspace opacity seen throughout bilateral lung predominantly within lateral aspect left lower lung worsening diffuse airspace disease noted throughout lung interval worsening diffuse bilateral multifocal pneumonia diffuse haziness lung consistent clinical concern ards change right worse comparison left significant change bilateral airspace opacity interstitial prominence prior study persistent perhaps somewhat diffuse bilateral airspace disease multifocal consolidation atelectasis significantly involving lingulaleft lower lobe small left pleural effusion extensive airspace disease throughout lung show improvement largely unchanged extensive bilateral airspace opacity diffuse multifocal consolidation involving lung seen worsened    1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    ..
# scattered focus ground glass opacity lobe lung right upper lobe atelectasis ncreased bilateral lower lung right midlung airspace opacity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            1
# subtle hazy opacity lung base                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# haziness left cardiac border increasing airspace opacity right upper lobe increased left pleural effusion consolidation andor atelectasis left lower lobe                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# hazy airspace opacity seen throughout bilateral lower lung right greater left worsening bilateral lower lobe opacity consistent airspace disease much dense retrocardiac left lower lobe consistent consolidation                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   1
# hypoinflated lung minimal bibasilar opacity                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Name: Radiologist KEY FINDINGS, Length: 99, dtype: int64

# %%
ohe=pd.get_dummies(data=dataset['Radiologist KEY FINDINGS'])
ohe.head
# Out:
# <bound method NDFrame.head of      acute disease focal pneumonia  ...  upper lobe predominant emphysema lung appear clear evidence airspace consolidation lung remain clear pleural effusion small rightsided pneumothorax subcutaneous emphysema right lateral chest wall left lower lobe atelectasis focal airspace opacification pleural effusion mild atelectatic change right lung base focal consolidation left lung appears clear
# 1                                0  ...                                                  0
# 2                                0  ...                                                  0
# 4                                0  ...                                                  0
# 7                                0  ...                                                  0
# 9                                0  ...                                                  0
# ..                             ...  ...                                                ...
# 246                              0  ...                                                  0
# 251                              0  ...                                                  0
# 253                              0  ...                                                  0
# 254                              0  ...                                                  0
# 256                              0  ...                                                  0
#
# [105 rows x 99 columns]>
